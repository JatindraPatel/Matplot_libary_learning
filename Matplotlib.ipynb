# %% [markdown]
# <a href="https://colab.research.google.com/github/JatindraPatel/Matplot_libary_learning/blob/main/Matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Matplotlib** :-

# %% [markdown]
# 1. Matplotlib is a powerful Python library used to create data visualizations such as charts, graphs, and plots.
#
# 2. It helps to represent data visually, making it easier to understand trends, patterns, and relationships.
#
# 3. The main module used for plotting is matplotlib.pyplot, usually imported as plt.
#
# 4. Matplotlib works like a drawing tool, where you can draw lines, bars, circles, and shapes to represent data.
#
# 5. It is commonly used with NumPy, Pandas, and SciPy for data analysis and scientific computing.
#
# 6. It allows creation of both 2D and basic 3D plots.
#
# 7. Charts can be customized easily — you can change colors, labels, titles, legends, gridlines, and much more.
#
# 8. It can save plots in different file formats like .png, .jpg, .pdf, .svg, etc.
#
# 9. Matplotlib is often used in data science, machine learning, and AI projects to display results.
#
# 10. It is open-source and free to use for everyone.

# %% [markdown]
# # DIff. b/w Pandas & Matplotlib.. :-
#
#  **Pandas is used for data manipulation and analysis, while Matplotlib is used for data visualization**

# %% [markdown]
# # Types of Charts in Matplotlib
#
# | Chart Type       | Function             | Purpose                                 |
# | ---------------- | -------------------- | --------------------------------------- |
# | **Line Chart**   | `plt.plot()`         | Show trends or change over time         |
# | **Bar Chart**    | `plt.bar()`          | Compare data between groups             |
# | **Pie Chart**    | `plt.pie()`          | Show parts of a whole                   |
# | **Scatter Plot** | `plt.scatter()`      | Show relationship between two variables |
# | **Histogram**    | `plt.hist()`         | Show frequency distribution of data     |
# | **Box Plot**     | `plt.boxplot()`      | Show data spread and outliers           |
# | **Area Plot**    | `plt.fill_between()` | Show cumulative trends over time        |

# %% [markdown]
# # Advantages of Matplotlib
#
# 1. Easy to learn and use.
#
# 2. Supports a wide variety of plots.
#
# 3. Works well with Pandas DataFrames.
#
# 4. Highly customizable and professional-looking.
#
# 5. Useful for both beginners and advanced data analysts.

# %%
import matplotlib.pyplot as plt
plt.plot([1,2,3,5],[4,5,1,6])
plt.show()

# %%
import matplotlib.pyplot as plt
x=[5,2,7]
y=[1,10,4]
plt.plot(x,y)
plt.title("Line Graph")
plt.ylabel("Y-axis")
plt.xlabel("X-axis")
plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot([11,12,2,24,15,6], marker='o',
         markersize=5,
         markerfacecolor='red')
plt.title("Line Graph")
plt.ylabel("Y-axis")
plt.xlabel("X-axis")
plt.show()

# %%
import matplotlib.pyplot as plt
x=[2,20,35]
y=[0,45,15]
plt.plot(x,y,'o',color='red')
plt.show()

# %%
import matplotlib.pyplot as plt
x=[9,3,4,0,7,3,5,6,6,4]
y=[6,2,6,6,8,4,0,5,2,9]
plt.title("Line Chart")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.plot(x,y,marker='o',
         markersize = '5')
plt.show()

# %%
import matplotlib.pyplot as plt
y=[3, 8, 1, 10, 5, 7]
plt.plot(y,marker='*',markersize=5.4, linewidth=1,color='black',markerfacecolor='green')
plt.title("Line- Chart ")
plt.xlabel=("X-axis")
plt.ylabel=("Y-axis")
plt.show()

# %% [markdown]
# #                          **Marker Reference**
#
#
# ---
#
#
#
# **We can choose any of these markers:**
#
# 'o'	Circle
#
# '*'	Star
#
# '.'	Point
#
# ','	Pixel
#
# 'x'	X
#
# 'X'	X (filled)
#
# '+'	Plus
#
# 'P'	Plus (filled)
#
# 's'	Square
#
# 'D'	Diamond
#
# 'd'	Diamond (thin)
#
# 'p'	Pentagon
#
# 'H'	Hexagon
#
# 'h'	Hexagon
#
# 'v'	Triangle Down
#
# '^'	Triangle Up
#
# '<'	Triangle Left
#
# '>'	Triangle Right
#
# '1'	Tri Down
#
# '2'	Tri Up
#
# '3'	Tri Left
#
# '4'	Tri Right
#
# '|'	Vline
#
# '_'	Hline

# %% [markdown]
# # **Color Reference**
#
# ---
#
#
#
#
#
# 1. 'r'	          Red
# 2. 'g'	          Green
# 3. 'b'          	Blue
# 4. 'c'          	Cyan
# 5. 'm'           	Magenta
# 6. 'y'	          Yellow
# 7. 'k'           	Black
# 8. 'w'           	White

# %% [markdown]
# # **Line Reference**
#
# ---
#
#
#
# 1. '-'     ------------->  	  Solid line
# 2. ':'	   ------------->  	  Dotted line
# 3. '--'	   ------------->  	  Dashed line
# 4. '-.'	   ------------->  	  Dashed/dotted line

# %%
import matplotlib.pyplot as plt
y=([9,3,4,0,7,3,5,6,6,4])
plt.title("Line Chart")
plt.plot(x, 'o:r')
plt.show()

# %%
import matplotlib.pyplot as plt
y=([9,3,4,0,7,3,5,6,6,4])
plt.title("Line Chart")
plt.plot(x, 'o-b')
plt.show()

# %%
import matplotlib.pyplot as plt
y=([9,3,4,0,7,3,5,6,6,4])
plt.title("Line Chart")
plt.plot(x, 'o--c')
plt.show()

# %%
import matplotlib.pyplot as plt
y=([9,3,4,0,7,3,5,6,6,4])
plt.title("Line Chart")
plt.plot(x, 'o-.m')
plt.show()

# %% [markdown]
# # 18-11-2025
#
# # Some ShortForms are used :-
#
#
# .... Markerfacecolor   ---------> mfc
#
#
# .... Markeredgecolor   ---------> mec
#
#
# .... Markersize   --------->    ms
#
#
# .... Linewidth     --------->   lw
#
#
# .... Linestyle     ---------> ls
#
#
# .... color   ---------> c

# %%
import matplotlib.pyplot as plt

y1=[9,3,4,0,7,3,5,6,6,4]
y2=[6,2,6,6,8,4,0,5,2,9]

plt.plot(y1,marker='*',mfc='b',mec='r')
plt.plot(y2,marker='*',mfc='b',mec='r')

plt.show()
